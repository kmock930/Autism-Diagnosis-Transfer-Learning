# %% [markdown]
# ## This notebook is used to load and extract video data into keyframes images

# %%
import cv2
import numpy as np
import os
import random

# %%
# extract key frames from video
def extract_key_frames(video_path, num_frames=10):
    # generate capture from video by using cv
    cap = cv2.VideoCapture(video_path)
    frames = []
    key_frames = []
    success, frame = cap.read()
    

    while success:
        # read frame 
        frames.append(frame)
        success, frame = cap.read()


    # release capture
    cap.release()

    # if no frames return null
    total_frames = len(frames)
    if total_frames == 0:
        return []
    
    
    diffs = []
    for i in range(1, total_frames):
        # calculate the difference between each frame
        diff = cv2.absdiff(cv2.cvtColor(frames[i], cv2.COLOR_BGR2GRAY),
                           cv2.cvtColor(frames[i-1], cv2.COLOR_BGR2GRAY))
        diff_sum = np.sum(diff)
        diffs.append(diff_sum)
        
    if len(diffs) == 0:
        key_frame_indices = [0]
    else:
        # find the frame with max difference
        sorted_indices = np.argsort(diffs)[::-1]  # "::-1" means index of frames with the highest variance
        key_frame_indices = sorted_indices[:num_frames]

    # sort the indices
    key_frame_indices = sorted(set(key_frame_indices))  

    for idx in key_frame_indices:
        key_frames.append(frames[idx])

    return key_frames

# %%
# define the path of violence data
Violence_positive_video_dir = './data/violence_dataset/Violence'
violence_positive_out_dir = './key_frames/violence/set1'

# define the path of non-violence data
Violence_negative_video_dir = './data/violence_dataset/NonViolence'
violence_negative_out_dir = './key_frames/violence/set0'

# define the path of harmful data
tiktok_positive_video_dir = './data/tiktok/train/Harmful Content'
tiktok_positive_out_dir = './key_frames/tiktok/set1'

# define the path of safe data
tiktok_negative_video_dir = './data/tiktok/train/Safe'
tiktok_negative_out_dir = './key_frames/tiktok/set0'

# %%
# extract keyframes from files path
def extract_keyframes_from_files(video_dir,output_dir, num_frames=10,num_of_sample=100):
    
    video_files = [f for f in os.listdir(tiktok_negative_video_dir) if f.endswith('.mp4')]
    sample_video_files = random.sample(video_files,num_of_sample)
    for video_file in sample_video_files:
        video_path = os.path.join(video_dir, video_file)
        print(f"now extract keyframes from file: {video_file}...")
        key_frames = extract_key_frames(video_path, num_frames = num_frames)
        output_dir_temp = os.path.join(output_dir, os.path.splitext(video_file)[0])
        os.makedirs(output_dir_temp, exist_ok=True)
        
        for i, frame in enumerate(key_frames):
            frame_path = os.path.join(output_dir_temp, f'key_frame_{i}.jpg')
            cv2.imwrite(frame_path, frame)

# %%
extract_keyframes_from_files(Violence_positive_video_dir,violence_positive_out_dir)
# Out:
# now extract keyframes from file: V_581.mp4...
# now extract keyframes from file: V_834.mp4...
# now extract keyframes from file: V_394.mp4...
# now extract keyframes from file: V_968.mp4...
# now extract keyframes from file: V_166.mp4...
# now extract keyframes from file: V_537.mp4...
# now extract keyframes from file: V_465.mp4...
# now extract keyframes from file: V_981.mp4...
# now extract keyframes from file: V_60.mp4...
# now extract keyframes from file: V_895.mp4...
# now extract keyframes from file: V_734.mp4...
# now extract keyframes from file: V_594.mp4...
# now extract keyframes from file: V_475.mp4...
# now extract keyframes from file: V_45.mp4...
# now extract keyframes from file: V_648.mp4...
# now extract keyframes from file: V_248.mp4...
# now extract keyframes from file: V_757.mp4...
# now extract keyframes from file: V_872.mp4...
# now extract keyframes from file: V_291.mp4...
# now extract keyframes from file: V_483.mp4...
# now extract keyframes from file: V_340.mp4...
# now extract keyframes from file: V_860.mp4...
# now extract keyframes from file: V_162.mp4...
# now extract keyframes from file: V_315.mp4...
# now extract keyframes from file: V_249.mp4...
# now extract keyframes from file: V_785.mp4...
# now extract keyframes from file: V_119.mp4...
# now extract keyframes from file: V_316.mp4...
# now extract keyframes from file: V_878.mp4...
# now extract keyframes from file: V_259.mp4...
# now extract keyframes from file: V_645.mp4...
# now extract keyframes from file: V_688.mp4...
# now extract keyframes from file: V_454.mp4...
# now extract keyframes from file: V_206.mp4...
# now extract keyframes from file: V_24.mp4...
# now extract keyframes from file: V_874.mp4...
# now extract keyframes from file: V_961.mp4...
# now extract keyframes from file: V_786.mp4...
# now extract keyframes from file: V_705.mp4...
# now extract keyframes from file: V_524.mp4...
# now extract keyframes from file: V_433.mp4...
# now extract keyframes from file: V_547.mp4...
# now extract keyframes from file: V_354.mp4...
# now extract keyframes from file: V_413.mp4...
# now extract keyframes from file: V_767.mp4...
# now extract keyframes from file: V_505.mp4...
# now extract keyframes from file: V_869.mp4...
# now extract keyframes from file: V_103.mp4...
# now extract keyframes from file: V_375.mp4...
# now extract keyframes from file: V_904.mp4...
# now extract keyframes from file: V_546.mp4...
# now extract keyframes from file: V_428.mp4...
# now extract keyframes from file: V_720.mp4...
# now extract keyframes from file: V_794.mp4...
# now extract keyframes from file: V_430.mp4...
# now extract keyframes from file: V_973.mp4...
# now extract keyframes from file: V_759.mp4...
# now extract keyframes from file: V_997.mp4...
# now extract keyframes from file: V_890.mp4...
# now extract keyframes from file: V_468.mp4...
# now extract keyframes from file: V_150.mp4...
# now extract keyframes from file: V_515.mp4...
# now extract keyframes from file: V_529.mp4...
# now extract keyframes from file: V_906.mp4...
# now extract keyframes from file: V_976.mp4...
# now extract keyframes from file: V_683.mp4...
# now extract keyframes from file: V_157.mp4...
# now extract keyframes from file: V_934.mp4...
# now extract keyframes from file: V_238.mp4...
# now extract keyframes from file: V_640.mp4...
# now extract keyframes from file: V_712.mp4...
# now extract keyframes from file: V_7.mp4...
# now extract keyframes from file: V_436.mp4...
# now extract keyframes from file: V_881.mp4...
# now extract keyframes from file: V_923.mp4...
# now extract keyframes from file: V_994.mp4...
# now extract keyframes from file: V_128.mp4...
# now extract keyframes from file: V_921.mp4...
# now extract keyframes from file: V_329.mp4...
# now extract keyframes from file: V_455.mp4...
# now extract keyframes from file: V_820.mp4...
# now extract keyframes from file: V_613.mp4...
# now extract keyframes from file: V_387.mp4...
# now extract keyframes from file: V_576.mp4...
# now extract keyframes from file: V_861.mp4...
# now extract keyframes from file: V_405.mp4...
# now extract keyframes from file: V_123.mp4...
# now extract keyframes from file: V_689.mp4...
# now extract keyframes from file: V_770.mp4...
# now extract keyframes from file: V_856.mp4...
# now extract keyframes from file: V_50.mp4...
# now extract keyframes from file: V_116.mp4...
# now extract keyframes from file: V_164.mp4...
# now extract keyframes from file: V_158.mp4...
# now extract keyframes from file: V_721.mp4...
# now extract keyframes from file: V_17.mp4...
# now extract keyframes from file: V_987.mp4...
# now extract keyframes from file: V_956.mp4...
# now extract keyframes from file: V_265.mp4...
# now extract keyframes from file: V_421.mp4...

# %%
extract_keyframes_from_files(Violence_negative_video_dir,violence_negative_out_dir)
# Out:
# now extract keyframes from file: NV_268.mp4...
# now extract keyframes from file: NV_383.mp4...
# now extract keyframes from file: NV_183.mp4...
# now extract keyframes from file: NV_159.mp4...
# now extract keyframes from file: NV_437.mp4...
# now extract keyframes from file: NV_985.mp4...
# now extract keyframes from file: NV_495.mp4...
# now extract keyframes from file: NV_178.mp4...
# now extract keyframes from file: NV_611.mp4...
# now extract keyframes from file: NV_249.mp4...
# now extract keyframes from file: NV_639.mp4...
# now extract keyframes from file: NV_414.mp4...
# now extract keyframes from file: NV_46.mp4...
# now extract keyframes from file: NV_218.mp4...
# now extract keyframes from file: NV_182.mp4...
# now extract keyframes from file: NV_376.mp4...
# now extract keyframes from file: NV_480.mp4...
# now extract keyframes from file: NV_917.mp4...
# now extract keyframes from file: NV_346.mp4...
# now extract keyframes from file: NV_768.mp4...
# now extract keyframes from file: NV_518.mp4...
# now extract keyframes from file: NV_930.mp4...
# now extract keyframes from file: NV_913.mp4...
# now extract keyframes from file: NV_237.mp4...
# now extract keyframes from file: NV_484.mp4...
# now extract keyframes from file: NV_373.mp4...
# now extract keyframes from file: NV_275.mp4...
# now extract keyframes from file: NV_635.mp4...
# now extract keyframes from file: NV_627.mp4...
# now extract keyframes from file: NV_447.mp4...
# now extract keyframes from file: NV_409.mp4...
# now extract keyframes from file: NV_918.mp4...
# now extract keyframes from file: NV_854.mp4...
# now extract keyframes from file: NV_742.mp4...
# now extract keyframes from file: NV_666.mp4...
# now extract keyframes from file: NV_604.mp4...
# now extract keyframes from file: NV_962.mp4...
# now extract keyframes from file: NV_792.mp4...
# now extract keyframes from file: NV_367.mp4...
# now extract keyframes from file: NV_25.mp4...
# now extract keyframes from file: NV_841.mp4...
# now extract keyframes from file: NV_102.mp4...
# now extract keyframes from file: NV_723.mp4...
# now extract keyframes from file: NV_774.mp4...
# now extract keyframes from file: NV_170.mp4...
# now extract keyframes from file: NV_101.mp4...
# now extract keyframes from file: NV_318.mp4...
# now extract keyframes from file: NV_771.mp4...
# now extract keyframes from file: NV_462.mp4...
# now extract keyframes from file: NV_644.mp4...
# now extract keyframes from file: NV_605.mp4...
# now extract keyframes from file: NV_709.mp4...
# now extract keyframes from file: NV_386.mp4...
# now extract keyframes from file: NV_817.mp4...
# now extract keyframes from file: NV_549.mp4...
# now extract keyframes from file: NV_124.mp4...
# now extract keyframes from file: NV_231.mp4...
# now extract keyframes from file: NV_55.mp4...
# now extract keyframes from file: NV_670.mp4...
# now extract keyframes from file: NV_661.mp4...
# now extract keyframes from file: NV_986.mp4...
# now extract keyframes from file: NV_332.mp4...
# now extract keyframes from file: NV_822.mp4...
# now extract keyframes from file: NV_804.mp4...
# now extract keyframes from file: NV_217.mp4...
# now extract keyframes from file: NV_476.mp4...
# now extract keyframes from file: NV_301.mp4...
# now extract keyframes from file: NV_959.mp4...
# now extract keyframes from file: NV_239.mp4...
# now extract keyframes from file: NV_550.mp4...
# now extract keyframes from file: NV_524.mp4...
# now extract keyframes from file: NV_585.mp4...
# now extract keyframes from file: NV_977.mp4...
# now extract keyframes from file: NV_311.mp4...
# now extract keyframes from file: NV_328.mp4...
# now extract keyframes from file: NV_543.mp4...
# now extract keyframes from file: NV_702.mp4...
# now extract keyframes from file: NV_256.mp4...
# now extract keyframes from file: NV_733.mp4...
# now extract keyframes from file: NV_777.mp4...
# now extract keyframes from file: NV_609.mp4...
# now extract keyframes from file: NV_474.mp4...
# now extract keyframes from file: NV_941.mp4...
# now extract keyframes from file: NV_789.mp4...
# now extract keyframes from file: NV_120.mp4...
# now extract keyframes from file: NV_34.mp4...
# now extract keyframes from file: NV_161.mp4...
# now extract keyframes from file: NV_960.mp4...
# now extract keyframes from file: NV_969.mp4...
# now extract keyframes from file: NV_216.mp4...
# now extract keyframes from file: NV_208.mp4...
# now extract keyframes from file: NV_413.mp4...
# now extract keyframes from file: NV_180.mp4...
# now extract keyframes from file: NV_701.mp4...
# now extract keyframes from file: NV_402.mp4...
# now extract keyframes from file: NV_406.mp4...
# now extract keyframes from file: NV_191.mp4...
# now extract keyframes from file: NV_90.mp4...
# now extract keyframes from file: NV_575.mp4...
# now extract keyframes from file: NV_215.mp4...

# %%
extract_keyframes_from_files(tiktok_positive_video_dir,tiktok_positive_out_dir)
# Out:
# now extract keyframes from file: coreuk_6992883643353976070.mp4...
# now extract keyframes from file: diasmei_7328769514630368517.mp4...
# now extract keyframes from file: dylanjackson230_6896937102961937670.mp4...
# now extract keyframes from file: flffyegg_7321735344318254341.mp4...
# now extract keyframes from file: gobungynepal_7308253924073491720.mp4...
# now extract keyframes from file: bob.reese_7085983475299454254.mp4...
# now extract keyframes from file: vtvcab.tintuc_7183144405086342402.mp4...
# now extract keyframes from file: joescandrett_7248584533333904666.mp4...
# now extract keyframes from file: ratedrawtv_7267262321620258078.mp4...
# now extract keyframes from file: askinem_7319032656782740782.mp4...
# now extract keyframes from file: duowheelshub_7101432223336779014.mp4...
# now extract keyframes from file: alex.artfire_6692521856991235334.mp4...
# now extract keyframes from file: girl_xinh.sexy_7281318488881384705.mp4...
# now extract keyframes from file: josh_norton3_7312590065761570094.mp4...
# now extract keyframes from file: fixtard.com_7230148987838401793.mp4...
