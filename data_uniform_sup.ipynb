# %%
import os
import random
import math
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import Sequence

# %%
seed = 2042
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)

CLIP_LEN = 16          # 每个视频剪辑的帧数
RESIZE_HEIGHT = 128    # 帧的调整高度
CROP_SIZE = 108        # 裁剪高度
size2 = 200            # 裁剪宽度

# %%
class VideoDataGenerator(Sequence):
    def __init__(self, dataset_paths, labels, batch_size=1, shuffle=True, split='train'):
        self.dataset_paths = dataset_paths  # 视频文件的路径列表
        self.labels = labels                # 对应的视频标签列表
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.split = split
        self.on_epoch_end()
    
    def __len__(self):
        return int(np.floor(len(self.dataset_paths) / self.batch_size))
    
    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        batch_paths = [self.dataset_paths[k] for k in indexes]
        batch_labels = [self.labels[k] for k in indexes]
        X, y = self.__data_generation(batch_paths, batch_labels)
        return X, y
    
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.dataset_paths))
        if self.shuffle:
            np.random.shuffle(self.indexes)
    
    def __data_generation(self, batch_paths, batch_labels):
        X = []
        y = []
        for i, video_path in enumerate(batch_paths):
            frames = self.load_frames(video_path)
            if self.split == 'train':
                try:
                    frames = self.crop(frames, CLIP_LEN, CROP_SIZE, size2)
                    frames = self.random_flip(frames)
                    
                except ValueError:
                    frames = self.crop(frames, CLIP_LEN, CROP_SIZE, 152)
                frames = self.resize(frames)
            frames = self.normalize(frames)
            frames = self.to_tensor(frames)
            X.append(frames)
            y.append(batch_labels[i])
        X = np.array(X)
        y = np.array(y)
        return X, y
    
    def load_frames(self, video_path):
        cap = cv2.VideoCapture(video_path)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        frames = []
        total = frame_count
        skip = max(int(total / CLIP_LEN), 1)
        count = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            if count % skip == 0:
                frames.append(frame)
            count += 1
        cap.release()
        frames = np.array(frames).astype(np.uint8)
        return frames
    
    def resize(self, frames):
        resized_frames = []
        for frame in frames:
            frame = cv2.resize(frame, (128, 112), interpolation=cv2.INTER_LINEAR)
            resized_frames.append(frame)
        return np.array(resized_frames)
     
    def normalize(self, frames):
        return frames.astype(np.float32) / 255.0
    
    def to_tensor(self, frames):
        return np.transpose(frames, (3, 0, 1, 2))  # (channels, frames, height, width)
    
    def random_flip(self, frames):
        if random.random() < 0.5:
            frames = frames[:, :, ::-1, :]
        return frames
    
    def crop(self, frames, clip_len, crop_size, crop_size2):
        if frames.shape[0] > clip_len:
            time_index = random.randint(0, frames.shape[0] - clip_len)
        else:
            time_index = 0
        height_index = random.randint(0, frames.shape[1] - crop_size)
        width_index = random.randint(0, frames.shape[2] - crop_size2)
        frames = frames[time_index:time_index + clip_len, height_index:height_index + crop_size,
                        width_index:width_index + crop_size2, :]
        if frames.shape[0] < clip_len:
            pad_num = clip_len - frames.shape[0]
            frames = np.concatenate((frames, frames[:pad_num]), axis=0)
        return frames

# %%
violence_negative_dir = './data/violence_dataset/NonViolence'
violence_positive_dir = './data/violence_dataset/Violence'
tiktok_negative_dir = './data/tiktok/train/Safe'
tiktok_positive_dir = './data/tiktok/train/Harmful Content'

# %%
def sample_videos(directory, num_samples=100, split_ratios=(0.55, 0.15, 0.3)):
    all_videos = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.mp4')]
    sampled_videos = random.sample(all_videos, min(num_samples, len(all_videos)))
    train_size = int(len(sampled_videos) * split_ratios[0])
    val_size = int(len(sampled_videos) * split_ratios[1])
    train_videos = sampled_videos[:train_size]
    val_videos = sampled_videos[train_size:train_size+val_size]
    test_videos = sampled_videos[train_size+val_size:]
    return train_videos, val_videos, test_videos

# %%
# Violence 数据集
violence_negative_train, violence_negative_val, violence_negative_test = sample_videos(violence_negative_dir, 100)
violence_positive_train, violence_positive_val, violence_positive_test = sample_videos(violence_positive_dir, 100)

# TikTok 数据集
tiktok_negative_train, tiktok_negative_val, tiktok_negative_test = sample_videos(tiktok_negative_dir, 100)
tiktok_positive_train, tiktok_positive_val, tiktok_positive_test = sample_videos(tiktok_positive_dir, 100)

# %%
# Violence 数据集
violence_train_paths = violence_negative_train + violence_positive_train
violence_train_labels = [0]*len(violence_negative_train) + [1]*len(violence_positive_train)

violence_val_paths = violence_negative_val + violence_positive_val
violence_val_labels = [0]*len(violence_negative_val) + [1]*len(violence_positive_val)

violence_test_paths = violence_negative_test + violence_positive_test
violence_test_labels = [0]*len(violence_negative_test) + [1]*len(violence_positive_test)

# %%
# TikTok 数据集
tiktok_train_paths = tiktok_negative_train + tiktok_positive_train
tiktok_train_labels = [0]*len(tiktok_negative_train) + [1]*len(tiktok_positive_train)

tiktok_val_paths = tiktok_negative_val + tiktok_positive_val
tiktok_val_labels = [0]*len(tiktok_negative_val) + [1]*len(tiktok_positive_val)

tiktok_test_paths = tiktok_negative_test + tiktok_positive_test
tiktok_test_labels = [0]*len(tiktok_negative_test) + [1]*len(tiktok_positive_test)

# %%
preprocess_data_dir = './preprocess_data'
def preprocess_and_save(dataset_name, split_name, video_paths, labels):
    save_dir = os.path.join(preprocess_data_dir, dataset_name, split_name)
    os.makedirs(save_dir, exist_ok=True)
    set0_dir = os.path.join(save_dir, 'set0')
    set1_dir = os.path.join(save_dir, 'set1')
    os.makedirs(set0_dir, exist_ok=True)
    os.makedirs(set1_dir, exist_ok=True)
    
    data_generator = VideoDataGenerator(video_paths, labels, batch_size=1, shuffle=False, split=split_name)
    
    for i in range(len(data_generator)):
        X, y = data_generator[i]
        video_tensor = X[0]
        label = y[0]
        if label == 0:
            save_path = os.path.join(set0_dir, f'video_{i}.npy')
        else:
            save_path = os.path.join(set1_dir, f'video_{i}.npy')
        np.save(save_path, video_tensor)
        print(f'Saved preprocessed video {i} to {save_path}')

# %%
print('Processing Violence dataset...')

print('Processing training data...')
preprocess_and_save('violence', 'train', violence_train_paths, violence_train_labels)
# Out:
# Processing Violence dataset...
# Processing training data...
# Saved preprocessed video 0 to ./preprocess_data\violence\train\set0\video_0.npy
# Saved preprocessed video 1 to ./preprocess_data\violence\train\set0\video_1.npy
# Saved preprocessed video 2 to ./preprocess_data\violence\train\set0\video_2.npy
# Saved preprocessed video 3 to ./preprocess_data\violence\train\set0\video_3.npy
# Saved preprocessed video 4 to ./preprocess_data\violence\train\set0\video_4.npy
# Saved preprocessed video 5 to ./preprocess_data\violence\train\set0\video_5.npy
# Saved preprocessed video 6 to ./preprocess_data\violence\train\set0\video_6.npy
# Saved preprocessed video 7 to ./preprocess_data\violence\train\set0\video_7.npy
# Saved preprocessed video 8 to ./preprocess_data\violence\train\set0\video_8.npy
# Saved preprocessed video 9 to ./preprocess_data\violence\train\set0\video_9.npy
# Saved preprocessed video 10 to ./preprocess_data\violence\train\set0\video_10.npy
# Saved preprocessed video 11 to ./preprocess_data\violence\train\set0\video_11.npy
# Saved preprocessed video 12 to ./preprocess_data\violence\train\set0\video_12.npy
# Saved preprocessed video 13 to ./preprocess_data\violence\train\set0\video_13.npy
# Saved preprocessed video 14 to ./preprocess_data\violence\train\set0\video_14.npy
# Saved preprocessed video 15 to ./preprocess_data\violence\train\set0\video_15.npy
# Saved preprocessed video 16 to ./preprocess_data\violence\train\set0\video_16.npy
# Saved preprocessed video 17 to ./preprocess_data\violence\train\set0\video_17.npy
# Saved preprocessed video 18 to ./preprocess_data\violence\train\set0\video_18.npy
# Saved preprocessed video 19 to ./preprocess_data\violence\train\set0\video_19.npy
# Saved preprocessed video 20 to ./preprocess_data\violence\train\set0\video_20.npy
# Saved preprocessed video 21 to ./preprocess_data\violence\train\set0\video_21.npy
# Saved preprocessed video 22 to ./preprocess_data\violence\train\set0\video_22.npy
# Saved preprocessed video 23 to ./preprocess_data\violence\train\set0\video_23.npy
# Saved preprocessed video 24 to ./preprocess_data\violence\train\set0\video_24.npy
# Saved preprocessed video 25 to ./preprocess_data\violence\train\set0\video_25.npy
# Saved preprocessed video 26 to ./preprocess_data\violence\train\set0\video_26.npy
# Saved preprocessed video 27 to ./preprocess_data\violence\train\set0\video_27.npy
# Saved preprocessed video 28 to ./preprocess_data\violence\train\set0\video_28.npy
# Saved preprocessed video 29 to ./preprocess_data\violence\train\set0\video_29.npy
# Saved preprocessed video 30 to ./preprocess_data\violence\train\set0\video_30.npy
# Saved preprocessed video 31 to ./preprocess_data\violence\train\set0\video_31.npy
# Saved preprocessed video 32 to ./preprocess_data\violence\train\set0\video_32.npy
# Saved preprocessed video 33 to ./preprocess_data\violence\train\set0\video_33.npy
# Saved preprocessed video 34 to ./preprocess_data\violence\train\set0\video_34.npy
# Saved preprocessed video 35 to ./preprocess_data\violence\train\set0\video_35.npy
# Saved preprocessed video 36 to ./preprocess_data\violence\train\set0\video_36.npy
# Saved preprocessed video 37 to ./preprocess_data\violence\train\set0\video_37.npy
# Saved preprocessed video 38 to ./preprocess_data\violence\train\set0\video_38.npy
# Saved preprocessed video 39 to ./preprocess_data\violence\train\set0\video_39.npy
# Saved preprocessed video 40 to ./preprocess_data\violence\train\set0\video_40.npy
# Saved preprocessed video 41 to ./preprocess_data\violence\train\set0\video_41.npy
# Saved preprocessed video 42 to ./preprocess_data\violence\train\set0\video_42.npy
# Saved preprocessed video 43 to ./preprocess_data\violence\train\set0\video_43.npy
# Saved preprocessed video 44 to ./preprocess_data\violence\train\set0\video_44.npy
# Saved preprocessed video 45 to ./preprocess_data\violence\train\set0\video_45.npy
# Saved preprocessed video 46 to ./preprocess_data\violence\train\set0\video_46.npy
# Saved preprocessed video 47 to ./preprocess_data\violence\train\set0\video_47.npy
# Saved preprocessed video 48 to ./preprocess_data\violence\train\set0\video_48.npy
# Saved preprocessed video 49 to ./preprocess_data\violence\train\set0\video_49.npy
# Saved preprocessed video 50 to ./preprocess_data\violence\train\set0\video_50.npy
# Saved preprocessed video 51 to ./preprocess_data\violence\train\set0\video_51.npy
# Saved preprocessed video 52 to ./preprocess_data\violence\train\set0\video_52.npy
# Saved preprocessed video 53 to ./preprocess_data\violence\train\set0\video_53.npy
# Saved preprocessed video 54 to ./preprocess_data\violence\train\set0\video_54.npy
# Saved preprocessed video 55 to ./preprocess_data\violence\train\set1\video_55.npy
# Saved preprocessed video 56 to ./preprocess_data\violence\train\set1\video_56.npy
# Saved preprocessed video 57 to ./preprocess_data\violence\train\set1\video_57.npy
# Saved preprocessed video 58 to ./preprocess_data\violence\train\set1\video_58.npy
# Saved preprocessed video 59 to ./preprocess_data\violence\train\set1\video_59.npy
# Saved preprocessed video 60 to ./preprocess_data\violence\train\set1\video_60.npy
# Saved preprocessed video 61 to ./preprocess_data\violence\train\set1\video_61.npy
# Saved preprocessed video 62 to ./preprocess_data\violence\train\set1\video_62.npy
# Saved preprocessed video 63 to ./preprocess_data\violence\train\set1\video_63.npy
# Saved preprocessed video 64 to ./preprocess_data\violence\train\set1\video_64.npy
# Saved preprocessed video 65 to ./preprocess_data\violence\train\set1\video_65.npy
# Saved preprocessed video 66 to ./preprocess_data\violence\train\set1\video_66.npy
# Saved preprocessed video 67 to ./preprocess_data\violence\train\set1\video_67.npy
# Saved preprocessed video 68 to ./preprocess_data\violence\train\set1\video_68.npy
# Saved preprocessed video 69 to ./preprocess_data\violence\train\set1\video_69.npy
# Saved preprocessed video 70 to ./preprocess_data\violence\train\set1\video_70.npy
# Saved preprocessed video 71 to ./preprocess_data\violence\train\set1\video_71.npy
# Saved preprocessed video 72 to ./preprocess_data\violence\train\set1\video_72.npy
# Saved preprocessed video 73 to ./preprocess_data\violence\train\set1\video_73.npy
# Saved preprocessed video 74 to ./preprocess_data\violence\train\set1\video_74.npy
# Saved preprocessed video 75 to ./preprocess_data\violence\train\set1\video_75.npy
# Saved preprocessed video 76 to ./preprocess_data\violence\train\set1\video_76.npy
# Saved preprocessed video 77 to ./preprocess_data\violence\train\set1\video_77.npy
# Saved preprocessed video 78 to ./preprocess_data\violence\train\set1\video_78.npy
# Saved preprocessed video 79 to ./preprocess_data\violence\train\set1\video_79.npy
# Saved preprocessed video 80 to ./preprocess_data\violence\train\set1\video_80.npy
# Saved preprocessed video 81 to ./preprocess_data\violence\train\set1\video_81.npy
# Saved preprocessed video 82 to ./preprocess_data\violence\train\set1\video_82.npy
# Saved preprocessed video 83 to ./preprocess_data\violence\train\set1\video_83.npy
# Saved preprocessed video 84 to ./preprocess_data\violence\train\set1\video_84.npy
# Saved preprocessed video 85 to ./preprocess_data\violence\train\set1\video_85.npy
# Saved preprocessed video 86 to ./preprocess_data\violence\train\set1\video_86.npy
# Saved preprocessed video 87 to ./preprocess_data\violence\train\set1\video_87.npy
# Saved preprocessed video 88 to ./preprocess_data\violence\train\set1\video_88.npy
# Saved preprocessed video 89 to ./preprocess_data\violence\train\set1\video_89.npy
# Saved preprocessed video 90 to ./preprocess_data\violence\train\set1\video_90.npy
# Saved preprocessed video 91 to ./preprocess_data\violence\train\set1\video_91.npy
# Saved preprocessed video 92 to ./preprocess_data\violence\train\set1\video_92.npy
# Saved preprocessed video 93 to ./preprocess_data\violence\train\set1\video_93.npy
# Saved preprocessed video 94 to ./preprocess_data\violence\train\set1\video_94.npy
# Saved preprocessed video 95 to ./preprocess_data\violence\train\set1\video_95.npy
# Saved preprocessed video 96 to ./preprocess_data\violence\train\set1\video_96.npy
# Saved preprocessed video 97 to ./preprocess_data\violence\train\set1\video_97.npy
# Saved preprocessed video 98 to ./preprocess_data\violence\train\set1\video_98.npy
# Saved preprocessed video 99 to ./preprocess_data\violence\train\set1\video_99.npy
# Saved preprocessed video 100 to ./preprocess_data\violence\train\set1\video_100.npy
# Saved preprocessed video 101 to ./preprocess_data\violence\train\set1\video_101.npy
# Saved preprocessed video 102 to ./preprocess_data\violence\train\set1\video_102.npy
# Saved preprocessed video 103 to ./preprocess_data\violence\train\set1\video_103.npy
# Saved preprocessed video 104 to ./preprocess_data\violence\train\set1\video_104.npy
# Saved preprocessed video 105 to ./preprocess_data\violence\train\set1\video_105.npy
# Saved preprocessed video 106 to ./preprocess_data\violence\train\set1\video_106.npy
# Saved preprocessed video 107 to ./preprocess_data\violence\train\set1\video_107.npy
# Saved preprocessed video 108 to ./preprocess_data\violence\train\set1\video_108.npy
# Saved preprocessed video 109 to ./preprocess_data\violence\train\set1\video_109.npy

# %%
print('Processing validation data...')
preprocess_and_save('violence', 'val', violence_val_paths, violence_val_labels)
# Out:
# Processing validation data...
# Saved preprocessed video 0 to ./preprocess_data\violence\val\set0\video_0.npy
# Saved preprocessed video 1 to ./preprocess_data\violence\val\set0\video_1.npy
# Saved preprocessed video 2 to ./preprocess_data\violence\val\set0\video_2.npy
# Saved preprocessed video 3 to ./preprocess_data\violence\val\set0\video_3.npy
# Saved preprocessed video 4 to ./preprocess_data\violence\val\set0\video_4.npy
# Saved preprocessed video 5 to ./preprocess_data\violence\val\set0\video_5.npy
# Saved preprocessed video 6 to ./preprocess_data\violence\val\set0\video_6.npy
# Saved preprocessed video 7 to ./preprocess_data\violence\val\set0\video_7.npy
# Saved preprocessed video 8 to ./preprocess_data\violence\val\set0\video_8.npy
# Saved preprocessed video 9 to ./preprocess_data\violence\val\set0\video_9.npy
# Saved preprocessed video 10 to ./preprocess_data\violence\val\set0\video_10.npy
# Saved preprocessed video 11 to ./preprocess_data\violence\val\set0\video_11.npy
# Saved preprocessed video 12 to ./preprocess_data\violence\val\set0\video_12.npy
# Saved preprocessed video 13 to ./preprocess_data\violence\val\set0\video_13.npy
# Saved preprocessed video 14 to ./preprocess_data\violence\val\set0\video_14.npy
# Saved preprocessed video 15 to ./preprocess_data\violence\val\set1\video_15.npy
# Saved preprocessed video 16 to ./preprocess_data\violence\val\set1\video_16.npy
# Saved preprocessed video 17 to ./preprocess_data\violence\val\set1\video_17.npy
# Saved preprocessed video 18 to ./preprocess_data\violence\val\set1\video_18.npy
# Saved preprocessed video 19 to ./preprocess_data\violence\val\set1\video_19.npy
# Saved preprocessed video 20 to ./preprocess_data\violence\val\set1\video_20.npy
# Saved preprocessed video 21 to ./preprocess_data\violence\val\set1\video_21.npy
# Saved preprocessed video 22 to ./preprocess_data\violence\val\set1\video_22.npy
# Saved preprocessed video 23 to ./preprocess_data\violence\val\set1\video_23.npy
# Saved preprocessed video 24 to ./preprocess_data\violence\val\set1\video_24.npy
# Saved preprocessed video 25 to ./preprocess_data\violence\val\set1\video_25.npy
# Saved preprocessed video 26 to ./preprocess_data\violence\val\set1\video_26.npy
# Saved preprocessed video 27 to ./preprocess_data\violence\val\set1\video_27.npy
# Saved preprocessed video 28 to ./preprocess_data\violence\val\set1\video_28.npy
# Saved preprocessed video 29 to ./preprocess_data\violence\val\set1\video_29.npy

# %%
print('Processing test data...')
preprocess_and_save('violence', 'test', violence_test_paths, violence_test_labels)
# Out:
# Processing test data...
# Saved preprocessed video 0 to ./preprocess_data\violence\test\set0\video_0.npy
# Saved preprocessed video 1 to ./preprocess_data\violence\test\set0\video_1.npy
# Saved preprocessed video 2 to ./preprocess_data\violence\test\set0\video_2.npy
# Saved preprocessed video 3 to ./preprocess_data\violence\test\set0\video_3.npy
# Saved preprocessed video 4 to ./preprocess_data\violence\test\set0\video_4.npy
# Saved preprocessed video 5 to ./preprocess_data\violence\test\set0\video_5.npy
# Saved preprocessed video 6 to ./preprocess_data\violence\test\set0\video_6.npy
# Saved preprocessed video 7 to ./preprocess_data\violence\test\set0\video_7.npy
# Saved preprocessed video 8 to ./preprocess_data\violence\test\set0\video_8.npy
# Saved preprocessed video 9 to ./preprocess_data\violence\test\set0\video_9.npy
# Saved preprocessed video 10 to ./preprocess_data\violence\test\set0\video_10.npy
# Saved preprocessed video 11 to ./preprocess_data\violence\test\set0\video_11.npy
# Saved preprocessed video 12 to ./preprocess_data\violence\test\set0\video_12.npy
# Saved preprocessed video 13 to ./preprocess_data\violence\test\set0\video_13.npy
# Saved preprocessed video 14 to ./preprocess_data\violence\test\set0\video_14.npy
# Saved preprocessed video 15 to ./preprocess_data\violence\test\set0\video_15.npy
# Saved preprocessed video 16 to ./preprocess_data\violence\test\set0\video_16.npy
# Saved preprocessed video 17 to ./preprocess_data\violence\test\set0\video_17.npy
# Saved preprocessed video 18 to ./preprocess_data\violence\test\set0\video_18.npy
# Saved preprocessed video 19 to ./preprocess_data\violence\test\set0\video_19.npy
# Saved preprocessed video 20 to ./preprocess_data\violence\test\set0\video_20.npy
# Saved preprocessed video 21 to ./preprocess_data\violence\test\set0\video_21.npy
# Saved preprocessed video 22 to ./preprocess_data\violence\test\set0\video_22.npy
# Saved preprocessed video 23 to ./preprocess_data\violence\test\set0\video_23.npy
# Saved preprocessed video 24 to ./preprocess_data\violence\test\set0\video_24.npy
# Saved preprocessed video 25 to ./preprocess_data\violence\test\set0\video_25.npy
# Saved preprocessed video 26 to ./preprocess_data\violence\test\set0\video_26.npy
# Saved preprocessed video 27 to ./preprocess_data\violence\test\set0\video_27.npy
# Saved preprocessed video 28 to ./preprocess_data\violence\test\set0\video_28.npy
# Saved preprocessed video 29 to ./preprocess_data\violence\test\set0\video_29.npy
# Saved preprocessed video 30 to ./preprocess_data\violence\test\set1\video_30.npy
# Saved preprocessed video 31 to ./preprocess_data\violence\test\set1\video_31.npy
# Saved preprocessed video 32 to ./preprocess_data\violence\test\set1\video_32.npy
# Saved preprocessed video 33 to ./preprocess_data\violence\test\set1\video_33.npy
# Saved preprocessed video 34 to ./preprocess_data\violence\test\set1\video_34.npy
# Saved preprocessed video 35 to ./preprocess_data\violence\test\set1\video_35.npy
# Saved preprocessed video 36 to ./preprocess_data\violence\test\set1\video_36.npy
# Saved preprocessed video 37 to ./preprocess_data\violence\test\set1\video_37.npy
# Saved preprocessed video 38 to ./preprocess_data\violence\test\set1\video_38.npy
# Saved preprocessed video 39 to ./preprocess_data\violence\test\set1\video_39.npy
# Saved preprocessed video 40 to ./preprocess_data\violence\test\set1\video_40.npy
# Saved preprocessed video 41 to ./preprocess_data\violence\test\set1\video_41.npy
# Saved preprocessed video 42 to ./preprocess_data\violence\test\set1\video_42.npy
# Saved preprocessed video 43 to ./preprocess_data\violence\test\set1\video_43.npy
# Saved preprocessed video 44 to ./preprocess_data\violence\test\set1\video_44.npy
# Saved preprocessed video 45 to ./preprocess_data\violence\test\set1\video_45.npy
# Saved preprocessed video 46 to ./preprocess_data\violence\test\set1\video_46.npy
# Saved preprocessed video 47 to ./preprocess_data\violence\test\set1\video_47.npy
# Saved preprocessed video 48 to ./preprocess_data\violence\test\set1\video_48.npy
# Saved preprocessed video 49 to ./preprocess_data\violence\test\set1\video_49.npy
# Saved preprocessed video 50 to ./preprocess_data\violence\test\set1\video_50.npy
# Saved preprocessed video 51 to ./preprocess_data\violence\test\set1\video_51.npy
# Saved preprocessed video 52 to ./preprocess_data\violence\test\set1\video_52.npy
# Saved preprocessed video 53 to ./preprocess_data\violence\test\set1\video_53.npy
# Saved preprocessed video 54 to ./preprocess_data\violence\test\set1\video_54.npy
# Saved preprocessed video 55 to ./preprocess_data\violence\test\set1\video_55.npy
# Saved preprocessed video 56 to ./preprocess_data\violence\test\set1\video_56.npy
# Saved preprocessed video 57 to ./preprocess_data\violence\test\set1\video_57.npy
# Saved preprocessed video 58 to ./preprocess_data\violence\test\set1\video_58.npy
# Saved preprocessed video 59 to ./preprocess_data\violence\test\set1\video_59.npy

# %%
print('Processing TikTok dataset...')

print('Processing training data...')
preprocess_and_save('tiktok', 'train', tiktok_train_paths, tiktok_train_labels)
# Out:
# Processing TikTok dataset...
# Processing training data...
# Saved preprocessed video 0 to ./preprocess_data\tiktok\train\set0\video_0.npy
# Saved preprocessed video 1 to ./preprocess_data\tiktok\train\set0\video_1.npy
# Saved preprocessed video 2 to ./preprocess_data\tiktok\train\set0\video_2.npy
# Saved preprocessed video 3 to ./preprocess_data\tiktok\train\set0\video_3.npy
# Saved preprocessed video 4 to ./preprocess_data\tiktok\train\set0\video_4.npy
# Saved preprocessed video 5 to ./preprocess_data\tiktok\train\set0\video_5.npy
# Saved preprocessed video 6 to ./preprocess_data\tiktok\train\set0\video_6.npy
# Saved preprocessed video 7 to ./preprocess_data\tiktok\train\set0\video_7.npy
# Saved preprocessed video 8 to ./preprocess_data\tiktok\train\set0\video_8.npy
# Saved preprocessed video 9 to ./preprocess_data\tiktok\train\set0\video_9.npy
# Saved preprocessed video 10 to ./preprocess_data\tiktok\train\set0\video_10.npy
# Saved preprocessed video 11 to ./preprocess_data\tiktok\train\set0\video_11.npy
# Saved preprocessed video 12 to ./preprocess_data\tiktok\train\set0\video_12.npy
# Saved preprocessed video 13 to ./preprocess_data\tiktok\train\set0\video_13.npy
# Saved preprocessed video 14 to ./preprocess_data\tiktok\train\set0\video_14.npy
# Saved preprocessed video 15 to ./preprocess_data\tiktok\train\set0\video_15.npy
# Saved preprocessed video 16 to ./preprocess_data\tiktok\train\set0\video_16.npy
# Saved preprocessed video 17 to ./preprocess_data\tiktok\train\set0\video_17.npy
# Saved preprocessed video 18 to ./preprocess_data\tiktok\train\set0\video_18.npy
# Saved preprocessed video 19 to ./preprocess_data\tiktok\train\set0\video_19.npy
# Saved preprocessed video 20 to ./preprocess_data\tiktok\train\set0\video_20.npy
# Saved preprocessed video 21 to ./preprocess_data\tiktok\train\set0\video_21.npy
# Saved preprocessed video 22 to ./preprocess_data\tiktok\train\set0\video_22.npy
# Saved preprocessed video 23 to ./preprocess_data\tiktok\train\set0\video_23.npy
# Saved preprocessed video 24 to ./preprocess_data\tiktok\train\set0\video_24.npy
# Saved preprocessed video 25 to ./preprocess_data\tiktok\train\set0\video_25.npy
# Saved preprocessed video 26 to ./preprocess_data\tiktok\train\set0\video_26.npy
# Saved preprocessed video 27 to ./preprocess_data\tiktok\train\set0\video_27.npy
# Saved preprocessed video 28 to ./preprocess_data\tiktok\train\set0\video_28.npy
# Saved preprocessed video 29 to ./preprocess_data\tiktok\train\set0\video_29.npy
# Saved preprocessed video 30 to ./preprocess_data\tiktok\train\set0\video_30.npy
# Saved preprocessed video 31 to ./preprocess_data\tiktok\train\set0\video_31.npy
# Saved preprocessed video 32 to ./preprocess_data\tiktok\train\set0\video_32.npy
# Saved preprocessed video 33 to ./preprocess_data\tiktok\train\set0\video_33.npy
# Saved preprocessed video 34 to ./preprocess_data\tiktok\train\set0\video_34.npy
# Saved preprocessed video 35 to ./preprocess_data\tiktok\train\set0\video_35.npy
# Saved preprocessed video 36 to ./preprocess_data\tiktok\train\set0\video_36.npy
# Saved preprocessed video 37 to ./preprocess_data\tiktok\train\set0\video_37.npy
# Saved preprocessed video 38 to ./preprocess_data\tiktok\train\set0\video_38.npy
# Saved preprocessed video 39 to ./preprocess_data\tiktok\train\set0\video_39.npy
# Saved preprocessed video 40 to ./preprocess_data\tiktok\train\set0\video_40.npy
# Saved preprocessed video 41 to ./preprocess_data\tiktok\train\set0\video_41.npy
# Saved preprocessed video 42 to ./preprocess_data\tiktok\train\set0\video_42.npy
# Saved preprocessed video 43 to ./preprocess_data\tiktok\train\set0\video_43.npy
# Saved preprocessed video 44 to ./preprocess_data\tiktok\train\set0\video_44.npy
# Saved preprocessed video 45 to ./preprocess_data\tiktok\train\set0\video_45.npy
# Saved preprocessed video 46 to ./preprocess_data\tiktok\train\set0\video_46.npy
# Saved preprocessed video 47 to ./preprocess_data\tiktok\train\set0\video_47.npy
# Saved preprocessed video 48 to ./preprocess_data\tiktok\train\set0\video_48.npy
# Saved preprocessed video 49 to ./preprocess_data\tiktok\train\set0\video_49.npy
# Saved preprocessed video 50 to ./preprocess_data\tiktok\train\set0\video_50.npy
# Saved preprocessed video 51 to ./preprocess_data\tiktok\train\set0\video_51.npy
# Saved preprocessed video 52 to ./preprocess_data\tiktok\train\set0\video_52.npy
# Saved preprocessed video 53 to ./preprocess_data\tiktok\train\set0\video_53.npy
# Saved preprocessed video 54 to ./preprocess_data\tiktok\train\set0\video_54.npy
# Saved preprocessed video 55 to ./preprocess_data\tiktok\train\set1\video_55.npy
# Saved preprocessed video 56 to ./preprocess_data\tiktok\train\set1\video_56.npy
# Saved preprocessed video 57 to ./preprocess_data\tiktok\train\set1\video_57.npy
# Saved preprocessed video 58 to ./preprocess_data\tiktok\train\set1\video_58.npy
# Saved preprocessed video 59 to ./preprocess_data\tiktok\train\set1\video_59.npy
# Saved preprocessed video 60 to ./preprocess_data\tiktok\train\set1\video_60.npy
# Saved preprocessed video 61 to ./preprocess_data\tiktok\train\set1\video_61.npy
# Saved preprocessed video 62 to ./preprocess_data\tiktok\train\set1\video_62.npy
# Saved preprocessed video 63 to ./preprocess_data\tiktok\train\set1\video_63.npy
# Saved preprocessed video 64 to ./preprocess_data\tiktok\train\set1\video_64.npy
# Saved preprocessed video 65 to ./preprocess_data\tiktok\train\set1\video_65.npy
# Saved preprocessed video 66 to ./preprocess_data\tiktok\train\set1\video_66.npy
# Saved preprocessed video 67 to ./preprocess_data\tiktok\train\set1\video_67.npy
# Saved preprocessed video 68 to ./preprocess_data\tiktok\train\set1\video_68.npy
# Saved preprocessed video 69 to ./preprocess_data\tiktok\train\set1\video_69.npy
# Saved preprocessed video 70 to ./preprocess_data\tiktok\train\set1\video_70.npy
# Saved preprocessed video 71 to ./preprocess_data\tiktok\train\set1\video_71.npy
# Saved preprocessed video 72 to ./preprocess_data\tiktok\train\set1\video_72.npy
# Saved preprocessed video 73 to ./preprocess_data\tiktok\train\set1\video_73.npy
# Saved preprocessed video 74 to ./preprocess_data\tiktok\train\set1\video_74.npy
# Saved preprocessed video 75 to ./preprocess_data\tiktok\train\set1\video_75.npy
# Saved preprocessed video 76 to ./preprocess_data\tiktok\train\set1\video_76.npy
# Saved preprocessed video 77 to ./preprocess_data\tiktok\train\set1\video_77.npy
# Saved preprocessed video 78 to ./preprocess_data\tiktok\train\set1\video_78.npy
# Saved preprocessed video 79 to ./preprocess_data\tiktok\train\set1\video_79.npy
# Saved preprocessed video 80 to ./preprocess_data\tiktok\train\set1\video_80.npy
# Saved preprocessed video 81 to ./preprocess_data\tiktok\train\set1\video_81.npy
# Saved preprocessed video 82 to ./preprocess_data\tiktok\train\set1\video_82.npy
# Saved preprocessed video 83 to ./preprocess_data\tiktok\train\set1\video_83.npy
# Saved preprocessed video 84 to ./preprocess_data\tiktok\train\set1\video_84.npy
# Saved preprocessed video 85 to ./preprocess_data\tiktok\train\set1\video_85.npy
# Saved preprocessed video 86 to ./preprocess_data\tiktok\train\set1\video_86.npy
# Saved preprocessed video 87 to ./preprocess_data\tiktok\train\set1\video_87.npy
# Saved preprocessed video 88 to ./preprocess_data\tiktok\train\set1\video_88.npy
# Saved preprocessed video 89 to ./preprocess_data\tiktok\train\set1\video_89.npy
# Saved preprocessed video 90 to ./preprocess_data\tiktok\train\set1\video_90.npy
# Saved preprocessed video 91 to ./preprocess_data\tiktok\train\set1\video_91.npy
# Saved preprocessed video 92 to ./preprocess_data\tiktok\train\set1\video_92.npy
# Saved preprocessed video 93 to ./preprocess_data\tiktok\train\set1\video_93.npy
# Saved preprocessed video 94 to ./preprocess_data\tiktok\train\set1\video_94.npy
# Saved preprocessed video 95 to ./preprocess_data\tiktok\train\set1\video_95.npy
# Saved preprocessed video 96 to ./preprocess_data\tiktok\train\set1\video_96.npy
# Saved preprocessed video 97 to ./preprocess_data\tiktok\train\set1\video_97.npy
# Saved preprocessed video 98 to ./preprocess_data\tiktok\train\set1\video_98.npy
# Saved preprocessed video 99 to ./preprocess_data\tiktok\train\set1\video_99.npy
# Saved preprocessed video 100 to ./preprocess_data\tiktok\train\set1\video_100.npy
# Saved preprocessed video 101 to ./preprocess_data\tiktok\train\set1\video_101.npy
# Saved preprocessed video 102 to ./preprocess_data\tiktok\train\set1\video_102.npy
# Saved preprocessed video 103 to ./preprocess_data\tiktok\train\set1\video_103.npy
# Saved preprocessed video 104 to ./preprocess_data\tiktok\train\set1\video_104.npy
# Saved preprocessed video 105 to ./preprocess_data\tiktok\train\set1\video_105.npy
# Saved preprocessed video 106 to ./preprocess_data\tiktok\train\set1\video_106.npy
# Saved preprocessed video 107 to ./preprocess_data\tiktok\train\set1\video_107.npy
# Saved preprocessed video 108 to ./preprocess_data\tiktok\train\set1\video_108.npy
# Saved preprocessed video 109 to ./preprocess_data\tiktok\train\set1\video_109.npy

# %%
print('Processing validation data...')
preprocess_and_save('tiktok', 'val', tiktok_val_paths, tiktok_val_labels)
# Out:
# Processing validation data...
# Saved preprocessed video 0 to ./preprocess_data\tiktok\val\set0\video_0.npy
# Saved preprocessed video 1 to ./preprocess_data\tiktok\val\set0\video_1.npy
# Saved preprocessed video 2 to ./preprocess_data\tiktok\val\set0\video_2.npy
# Saved preprocessed video 3 to ./preprocess_data\tiktok\val\set0\video_3.npy
# Saved preprocessed video 4 to ./preprocess_data\tiktok\val\set0\video_4.npy
# Saved preprocessed video 5 to ./preprocess_data\tiktok\val\set0\video_5.npy
# Saved preprocessed video 6 to ./preprocess_data\tiktok\val\set0\video_6.npy
# Saved preprocessed video 7 to ./preprocess_data\tiktok\val\set0\video_7.npy
# Saved preprocessed video 8 to ./preprocess_data\tiktok\val\set0\video_8.npy
# Saved preprocessed video 9 to ./preprocess_data\tiktok\val\set0\video_9.npy
# Saved preprocessed video 10 to ./preprocess_data\tiktok\val\set0\video_10.npy
# Saved preprocessed video 11 to ./preprocess_data\tiktok\val\set0\video_11.npy
# Saved preprocessed video 12 to ./preprocess_data\tiktok\val\set0\video_12.npy
# Saved preprocessed video 13 to ./preprocess_data\tiktok\val\set0\video_13.npy
# Saved preprocessed video 14 to ./preprocess_data\tiktok\val\set0\video_14.npy
# Saved preprocessed video 15 to ./preprocess_data\tiktok\val\set1\video_15.npy
# Saved preprocessed video 16 to ./preprocess_data\tiktok\val\set1\video_16.npy
# Saved preprocessed video 17 to ./preprocess_data\tiktok\val\set1\video_17.npy
# Saved preprocessed video 18 to ./preprocess_data\tiktok\val\set1\video_18.npy
# Saved preprocessed video 19 to ./preprocess_data\tiktok\val\set1\video_19.npy
# Saved preprocessed video 20 to ./preprocess_data\tiktok\val\set1\video_20.npy
# Saved preprocessed video 21 to ./preprocess_data\tiktok\val\set1\video_21.npy
# Saved preprocessed video 22 to ./preprocess_data\tiktok\val\set1\video_22.npy
# Saved preprocessed video 23 to ./preprocess_data\tiktok\val\set1\video_23.npy
# Saved preprocessed video 24 to ./preprocess_data\tiktok\val\set1\video_24.npy
# Saved preprocessed video 25 to ./preprocess_data\tiktok\val\set1\video_25.npy
# Saved preprocessed video 26 to ./preprocess_data\tiktok\val\set1\video_26.npy
# Saved preprocessed video 27 to ./preprocess_data\tiktok\val\set1\video_27.npy
# Saved preprocessed video 28 to ./preprocess_data\tiktok\val\set1\video_28.npy
# Saved preprocessed video 29 to ./preprocess_data\tiktok\val\set1\video_29.npy

# %%
print('Processing test data...')
preprocess_and_save('tiktok', 'test', tiktok_test_paths, tiktok_test_labels)
# Out:
# Processing test data...
# Saved preprocessed video 0 to ./preprocess_data\tiktok\test\set0\video_0.npy
# Saved preprocessed video 1 to ./preprocess_data\tiktok\test\set0\video_1.npy
# Saved preprocessed video 2 to ./preprocess_data\tiktok\test\set0\video_2.npy
# Saved preprocessed video 3 to ./preprocess_data\tiktok\test\set0\video_3.npy
# Saved preprocessed video 4 to ./preprocess_data\tiktok\test\set0\video_4.npy
# Saved preprocessed video 5 to ./preprocess_data\tiktok\test\set0\video_5.npy
# Saved preprocessed video 6 to ./preprocess_data\tiktok\test\set0\video_6.npy
# Saved preprocessed video 7 to ./preprocess_data\tiktok\test\set0\video_7.npy
# Saved preprocessed video 8 to ./preprocess_data\tiktok\test\set0\video_8.npy
# Saved preprocessed video 9 to ./preprocess_data\tiktok\test\set0\video_9.npy
# Saved preprocessed video 10 to ./preprocess_data\tiktok\test\set0\video_10.npy
# Saved preprocessed video 11 to ./preprocess_data\tiktok\test\set0\video_11.npy
# Saved preprocessed video 12 to ./preprocess_data\tiktok\test\set0\video_12.npy
# Saved preprocessed video 13 to ./preprocess_data\tiktok\test\set0\video_13.npy
# Saved preprocessed video 14 to ./preprocess_data\tiktok\test\set0\video_14.npy
# Saved preprocessed video 15 to ./preprocess_data\tiktok\test\set0\video_15.npy
# Saved preprocessed video 16 to ./preprocess_data\tiktok\test\set0\video_16.npy
# Saved preprocessed video 17 to ./preprocess_data\tiktok\test\set0\video_17.npy
# Saved preprocessed video 18 to ./preprocess_data\tiktok\test\set0\video_18.npy
# Saved preprocessed video 19 to ./preprocess_data\tiktok\test\set0\video_19.npy
# Saved preprocessed video 20 to ./preprocess_data\tiktok\test\set0\video_20.npy
# Saved preprocessed video 21 to ./preprocess_data\tiktok\test\set0\video_21.npy
# Saved preprocessed video 22 to ./preprocess_data\tiktok\test\set0\video_22.npy
# Saved preprocessed video 23 to ./preprocess_data\tiktok\test\set0\video_23.npy
# Saved preprocessed video 24 to ./preprocess_data\tiktok\test\set0\video_24.npy
# Saved preprocessed video 25 to ./preprocess_data\tiktok\test\set0\video_25.npy
# Saved preprocessed video 26 to ./preprocess_data\tiktok\test\set0\video_26.npy
# Saved preprocessed video 27 to ./preprocess_data\tiktok\test\set0\video_27.npy
# Saved preprocessed video 28 to ./preprocess_data\tiktok\test\set0\video_28.npy
# Saved preprocessed video 29 to ./preprocess_data\tiktok\test\set0\video_29.npy
# Saved preprocessed video 30 to ./preprocess_data\tiktok\test\set1\video_30.npy
# Saved preprocessed video 31 to ./preprocess_data\tiktok\test\set1\video_31.npy
# Saved preprocessed video 32 to ./preprocess_data\tiktok\test\set1\video_32.npy
# Saved preprocessed video 33 to ./preprocess_data\tiktok\test\set1\video_33.npy
# Saved preprocessed video 34 to ./preprocess_data\tiktok\test\set1\video_34.npy
# Saved preprocessed video 35 to ./preprocess_data\tiktok\test\set1\video_35.npy
# Saved preprocessed video 36 to ./preprocess_data\tiktok\test\set1\video_36.npy
# Saved preprocessed video 37 to ./preprocess_data\tiktok\test\set1\video_37.npy
# Saved preprocessed video 38 to ./preprocess_data\tiktok\test\set1\video_38.npy
# Saved preprocessed video 39 to ./preprocess_data\tiktok\test\set1\video_39.npy
# Saved preprocessed video 40 to ./preprocess_data\tiktok\test\set1\video_40.npy
# Saved preprocessed video 41 to ./preprocess_data\tiktok\test\set1\video_41.npy
# Saved preprocessed video 42 to ./preprocess_data\tiktok\test\set1\video_42.npy
# Saved preprocessed video 43 to ./preprocess_data\tiktok\test\set1\video_43.npy
# Saved preprocessed video 44 to ./preprocess_data\tiktok\test\set1\video_44.npy
# Saved preprocessed video 45 to ./preprocess_data\tiktok\test\set1\video_45.npy
# Saved preprocessed video 46 to ./preprocess_data\tiktok\test\set1\video_46.npy
# Saved preprocessed video 47 to ./preprocess_data\tiktok\test\set1\video_47.npy
# Saved preprocessed video 48 to ./preprocess_data\tiktok\test\set1\video_48.npy
# Saved preprocessed video 49 to ./preprocess_data\tiktok\test\set1\video_49.npy
# Saved preprocessed video 50 to ./preprocess_data\tiktok\test\set1\video_50.npy
# Saved preprocessed video 51 to ./preprocess_data\tiktok\test\set1\video_51.npy
# Saved preprocessed video 52 to ./preprocess_data\tiktok\test\set1\video_52.npy
# Saved preprocessed video 53 to ./preprocess_data\tiktok\test\set1\video_53.npy
# Saved preprocessed video 54 to ./preprocess_data\tiktok\test\set1\video_54.npy
# Saved preprocessed video 55 to ./preprocess_data\tiktok\test\set1\video_55.npy
# Saved preprocessed video 56 to ./preprocess_data\tiktok\test\set1\video_56.npy
# Saved preprocessed video 57 to ./preprocess_data\tiktok\test\set1\video_57.npy
# Saved preprocessed video 58 to ./preprocess_data\tiktok\test\set1\video_58.npy
# Saved preprocessed video 59 to ./preprocess_data\tiktok\test\set1\video_59.npy

# %%
def balanced_batch_generator(dataset, labels, n_classes, n_samples):
    label_set = np.unique(labels)
    label_to_indices = {label: np.where(labels == label)[0] for label in label_set}
    used_label_indices_count = {label: 0 for label in label_set}
    
    while True:
        classes = np.random.choice(label_set, n_classes, replace=False)
        batch_indices = []
        for class_ in classes:
            indices = label_to_indices[class_]
            start = used_label_indices_count[class_]
            end = start + n_samples
            if end > len(indices):
                np.random.shuffle(indices)
                used_label_indices_count[class_] = 0
                start = 0
                end = n_samples
            batch_indices.extend(indices[start:end])
            used_label_indices_count[class_] += n_samples
        batch_data = dataset[batch_indices]
        batch_labels = labels[batch_indices]
        yield batch_data, batch_labels
